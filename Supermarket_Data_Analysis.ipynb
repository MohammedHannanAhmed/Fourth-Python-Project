# %%
import pandas as pd
import numpy as np
from random import randint, choice
from datetime import datetime, timedelta

# Sample Data
customers = range(1, 101)
genders = ['Male', 'Female']
product_subcategories = ['Fruits', 'Vegetables', 'Dairy', 'Bakery', 'Meat', 'Seafood', 'Beverages', 'Snacks', 'Frozen Foods', 'Cleaning Supplies']
start_date = datetime.now() - timedelta(days=730)
end_date = datetime.now()

# Create the dataset
data = []

for customer_id in customers:
    age = randint(18, 75)
    gender = choice(genders)
    num_products = randint(1, 10)
    purchase_date = start_date + (end_date - start_date) * np.random.random()
    purchase_date = purchase_date.strftime('%Y-%m-%d')

    for _ in range(num_products):
        subcategory = choice(product_subcategories)
        quantity = randint(1, 20)
        data.append([customer_id, age, gender, subcategory, purchase_date, quantity])

# Create a DataFrame
columns = ['Customer ID', 'Customer Age', 'Customer Gender', 'Product Subcategory', 'Date', 'Quantity Purchased']
df = pd.DataFrame(data, columns=columns)

# Save to Excel
df.to_excel('SupermarketData.xlsx', index=False)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

df = pd.read_excel('SupermarketData.xlsx')

# %%
import plotly.express as px

# Group by product subcategory and sum the quantities
subcategory_totals = df.groupby('Product Subcategory')['Quantity Purchased'].sum().reset_index()

# Create interactive bar chart
fig = px.bar(subcategory_totals, x='Product Subcategory', y='Quantity Purchased',
             title='Total Quantity Purchased by Product Subcategory',
             labels={'Product Subcategory': 'Product Subcategory', 'Quantity Purchased': 'Total Quantity Purchased'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="0116fd57-d95f-4138-af60-37caab49e015" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0116fd57-d95f-4138-af60-37caab49e015")) {                    Plotly.newPlot(                        "0116fd57-d95f-4138-af60-37caab49e015",                        [{"alignmentgroup":"True","hovertemplate":"Product Subcategory=%{x}\u003cbr\u003eTotal Quantity Purchased=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Bakery","Beverages","Cleaning Supplies","Dairy","Frozen Foods","Fruits","Meat","Seafood","Snacks","Vegetables"],"xaxis":"x","y":[583,516,466,683,521,733,541,510,465,633],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode": ...

# %%
# Count the number of customers by gender
gender_counts = df['Customer Gender'].value_counts().reset_index()
gender_counts.columns = ['Customer Gender', 'Count']

# Create interactive pie chart
fig = px.pie(gender_counts, values='Count', names='Customer Gender',
             title='Gender Distribution of Customers',
             labels={'Customer Gender': 'Gender', 'Count': 'Count'},
             hole=0.3)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="4d43591b-618d-4d9e-b3b1-3d1bb27fa215" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4d43591b-618d-4d9e-b3b1-3d1bb27fa215")) {                    Plotly.newPlot(                        "4d43591b-618d-4d9e-b3b1-3d1bb27fa215",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.3,"hovertemplate":"Gender=%{label}\u003cbr\u003eCount=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Male","Female"],"legendgroup":"","name":"","showlegend":true,"values":[332,217],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"m ...

# %%
# Create interactive histogram
fig = px.histogram(df, x='Customer Age', nbins=15,
                   title='Customer Age Distribution',
                   labels={'Customer Age': 'Age', 'count': 'Frequency'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d19012d0-0224-4310-87a0-699c9eb069ba" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d19012d0-0224-4310-87a0-699c9eb069ba")) {                    Plotly.newPlot(                        "d19012d0-0224-4310-87a0-699c9eb069ba",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Age=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","nbinsx":15,"offsetgroup":"","orientation":"v","showlegend":false,"x":[69,69,69,69,69,69,69,50,62,62,62,62,62,62,62,62,62,59,59,59,59,59,59,74,74,74,74,74,74,74,74,74,55,55,29,29,29,29,29,29,29,29,55,55,55,20,20,20,20,20,20,20,46,46,46,46,46,46,46,46,46,46,28,28,28,28,28,28,28,28,28,70,70,46,46,46,55,55,55,74,74,74,74,74,74,39,39,39,39,39,39,39,39,61,61,61,61,61,61,61,61,61,61,61,61,61,57,57,57,57,57,57,41,41,41,41,41,41,41,41,52,52,52,52,52,52,52,52,52,52,30,30,75,75,75,75,75,75,75,75,75,75,75,75,35,35,35,35,35,55,55,55,36,36,36,36,36,70,70,70,70,70,70,70,61,61,61,61,67,67,67,75,66,66,66,66,66,66,66,66,66,66,25,25,25,25,25,25,25,25,25,25,27,27,27,27,27,50,50,50,50,50,50,50,32,32,32,32,32,32,32,32,28,28,28,28,28,28,28,28,29,29,29,29,29,29,29,29,29,70,70,70,68,68,41,41,41,41,41,41,44,44,44,44,44,44,24,24,24,24,24,59,59,59,59,59,59,59,59,54,54,54,54,54,54,54,58,58,58,58,58,58,28,28,28,28,28,28,46,46,46,46,46,42,21,21,21,21,21,21,40,40,40,40,40,40,40,40,40,40,66,66,66,66,66,66,66,53,53,53,53,53,53,53,62,62,62,62,62,33,33,33,33,69,69,69,69,69,26,26,26,62,62,62,62,62,58,58,58,58,58,46,46,46,46,46,46,46,46,46,33,74,74,74,74,74,74,74,37,37,37,37,31,32,32,32,32,75,75,75,42,39,39,39,39,39,39,39,39,22,22,22,22,22,22,22,22,22,22,74,74,74,66,66,66,66,71,71,71,71,71,68,68,65,65,66,66,66,66,66,26,26,26,26,26,39,39,39,39,58,58,62,62,62,44,44,44,52,52,52,52,52,52,52,52,52,30,30,30,30,30,30,30,30,30,30,44,44,44,44,44,44,44,44,44,33,57,57,57,57,57,57,57,57,57,19,19,32,32,32,32,32,32,32,52,52,52,52,52,52,26,26,26,26,67,67,45,45,45,45,45,45,45,45,45,74,74,74,74,74,74,74,74,74,74,55,55,74,74,74,74,74,74,74,40,40,40,40,40,40,40,40,42,42,42,31,31,31,31,31,31,55,55,55,55,55,23,23,23,23,23,23,23,23,52,52,52,52,52],"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.44444444 ...

# %%
# Create interactive box plot
fig = px.box(df, x='Product Subcategory', y='Quantity Purchased',
             title='Quantity Purchased by Product Subcategory',
             labels={'Product Subcategory': 'Product Subcategory', 'Quantity Purchased': 'Quantity Purchased'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="52338518-7d5e-47ef-a87b-69f3165cf209" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("52338518-7d5e-47ef-a87b-69f3165cf209")) {                    Plotly.newPlot(                        "52338518-7d5e-47ef-a87b-69f3165cf209",                        [{"alignmentgroup":"True","hovertemplate":"Product Subcategory=%{x}\u003cbr\u003eQuantity Purchased=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["Dairy","Beverages","Dairy","Fruits","Beverages","Vegetables","Bakery","Cleaning Supplies","Bakery","Bakery","Bakery","Dairy","Cleaning Supplies","Seafood","Seafood","Vegetables","Frozen Foods","Seafood","Meat","Beverages","Fruits","Seafood","Vegetables","Cleaning Supplies","Cleaning Supplies","Dairy","Cleaning Supplies","Meat","Fruits","Meat","Cleaning Supplies","Snacks","Vegetables","Meat","Cleaning Supplies","Fruits","Fruits","Seafood","Frozen Foods","Meat","Fruits","Vegetables","Bakery","Frozen Foods","Beverages","Seafood","Snacks","Cleaning Supplies","Vegetables","Fruits","Snacks","Vegetables","Dairy","Dairy","Cleaning Supplies","Seafood","Cleaning Supplies","Fruits","Frozen Foods","Snacks","Dairy","Dairy","Frozen Foods","Fruits","Fruits","Cleaning Supplies","Dairy","Dairy","Dairy","Cleaning Supplies","Snacks","Bakery","Bakery","Meat","Dairy","Cleaning Supplies","Meat","Vegetables","Frozen Foods","Cleaning Supplies","Fruits","Dairy","Cleaning Supplies","Vegetables","Dairy","Snacks","Dairy","Seafood","Dairy","Beverages","Meat","Vegetables","Cleaning Supplies","Dairy","Beverages","Meat","Dairy","Meat","Beverages","Bakery","Bakery","Snacks","Bakery","Frozen Foods","Cleaning Supplies","Beverages","Cleaning Supplies","Meat","Cleaning Supplies","Snacks","Beverages","Beverages","Beverages","Bakery","Beverages","Seafood","Vegetables","Snacks","Seafood","Frozen Foods","Cleaning Supplies","Beverages","Seafood","Vegetables","Meat","Snacks","Fruits","Beverages","Beverages","Vegetables","Fruits","Meat","Dairy","Snacks","Dairy","Meat","Seafood","Frozen Foods","Meat","Fruits","Frozen Foods","Bakery","Fruits","Cleaning Supplies","Snacks","Bakery","Snacks","Meat","Fruits","Beverages","Seafood","Frozen Foods","Fruits","Fruits","Bakery","Fruits","Frozen Foods","Bakery","Fruits","Fruits","Seafood","Vegetables","Frozen Foods","Bakery","Seafood","Fruits","Vegetables","Fruits","Bakery","Frozen Foods","Seafood","Bakery","Snacks","Dairy","Cleaning Supplies","Meat","Dairy","Vegetables","Seafood","Frozen Foods","Fruits","Beverages","Seafood","Vegetables","Fruits","Snacks","Fruits","Beverages","Dairy","Snacks","Vegetables","Dairy","Snacks","Fruits","Beverages","Vegetables","Bakery","Bakery","Seafood","Frozen Foods","Meat","Cleaning Supplies","Fruits","Vegetables","Cleaning Supplies","Dairy","Dairy","Frozen Foods","Bakery","Seafood","Vegetables","Seafood","Frozen Foods","Seafood","Vegetables","Vegetables","Dairy","Beverages","Meat","Frozen Foods","Dairy","Seafood","Snacks","Fruits","Fruits","Snacks","Snacks","Dairy","Vegetables","Dairy","Seafood","Snacks","Meat","Bakery","Frozen Foods","Vegetables","Meat","Beverages","Bakery","Vegetables","Snacks","Beverages","Meat","Beverages","Dairy","Fruits","Dairy","Cleaning Supplies","Beverages","Vegetables","Dairy","Bakery","Beverages","Bakery","Cleaning Supplies","Cleaning Supplies","Frozen Foods","Dairy","Dairy","Fruits","Meat","Dairy","Cleaning Supplies","Vegetables","Meat","Beverages","Beverages","Dairy","Meat","Bakery","Frozen Foods","Seafood","Vegetables","Vegetables","Frozen Foods","Frozen Foods","Vegetables","Meat","Snacks","Meat","Bakery","Bakery","Seafood","Bakery","Snacks","Me ...

# %%
# Summarize data by product subcategory and gender
subcategory_gender_totals = df.groupby(['Product Subcategory', 'Customer Gender'])['Quantity Purchased'].sum().reset_index()

# Create interactive treemap
fig = px.treemap(subcategory_gender_totals, path=['Product Subcategory', 'Customer Gender'], values='Quantity Purchased',
                 title='Quantity Purchased by Product Subcategory and Gender',
                 labels={'Quantity Purchased': 'Total Quantity Purchased', 'Product Subcategory': 'Product Subcategory', 'Customer Gender': 'Gender'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="797b0a4f-535c-4127-8129-f243f29948ad" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("797b0a4f-535c-4127-8129-f243f29948ad")) {                    Plotly.newPlot(                        "797b0a4f-535c-4127-8129-f243f29948ad",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}\u003cbr\u003eTotal Quantity Purchased=%{value}\u003cbr\u003eparent=%{parent}\u003cbr\u003eid=%{id}\u003cextra\u003e\u003c\u002fextra\u003e","ids":["Bakery\u002fFemale","Beverages\u002fFemale","Cleaning Supplies\u002fFemale","Dairy\u002fFemale","Frozen Foods\u002fFemale","Fruits\u002fFemale","Meat\u002fFemale","Seafood\u002fFemale","Snacks\u002fFemale","Vegetables\u002fFemale","Bakery\u002fMale","Beverages\u002fMale","Cleaning Supplies\u002fMale","Dairy\u002fMale","Frozen Foods\u002fMale","Fruits\u002fMale","Meat\u002fMale","Seafood\u002fMale","Snacks\u002fMale","Vegetables\u002fMale","Bakery","Beverages","Cleaning Supplies","Dairy","Frozen Foods","Fruits","Meat","Seafood","Snacks","Vegetables"],"labels":["Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Bakery","Beverages","Cleaning Supplies","Dairy","Frozen Foods","Fruits","Meat","Seafood","Snacks","Vegetables"],"name":"","parents":["Bakery","Beverages","Cleaning Supplies","Dairy","Frozen Foods","Fruits","Meat","Seafood","Snacks","Vegetables","Bakery","Beverages","Cleaning Supplies","Dairy","Frozen Foods","Fruits","Meat","Seafood","Snacks","Vegetables","","","","","","","","","",""],"values":[268,201,141,262,212,265,211,256,232,254,315,315,325,421,309,468,330,254,233,379,583,516,466,683,521,733,541,510,465,633],"type":"treemap"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3 ...

# %%
# Summarize data by customer age and product subcategory
age_subcategory_totals = df.groupby(['Customer Age', 'Product Subcategory'])['Quantity Purchased'].sum().reset_index()

# Create interactive bubble chart
fig = px.scatter(age_subcategory_totals, x='Customer Age', y='Quantity Purchased',
                 size='Quantity Purchased', color='Product Subcategory', hover_name='Product Subcategory',
                 title='Quantity Purchased by Customer Age and Product Subcategory',
                 labels={'Customer Age': 'Customer Age', 'Quantity Purchased': 'Quantity Purchased'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="45eb1857-c7b1-4a23-9a92-4d9d9910d779" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("45eb1857-c7b1-4a23-9a92-4d9d9910d779")) {                    Plotly.newPlot(                        "45eb1857-c7b1-4a23-9a92-4d9d9910d779",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eProduct Subcategory=Fruits\u003cbr\u003eCustomer Age=%{x}\u003cbr\u003eQuantity Purchased=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Fruits","Fruits","Fruits","Fruits","Fruits","Fruits","Fruits","Fruits","Fruits","Fruits","Fruits","Fruits","Fruits","Fruits","Fruits","Fruits","Fruits","Fruits","Fruits","Fruits","Fruits","Fruits","Fruits","Fruits","Fruits","Fruits","Fruits","Fruits","Fruits","Fruits","Fruits","Fruits","Fruits","Fruits"],"legendgroup":"Fruits","marker":{"color":"#636efa","size":[16,6,48,26,19,3,10,41,37,15,17,8,9,42,22,14,31,45,63,18,8,14,31,33,4,16,2,20,14,12,5,5,48,31],"sizemode":"area","sizeref":0.2175,"symbol":"circle"},"mode":"markers","name":"Fruits","orientation":"v","showlegend":true,"x":[19,20,23,25,26,27,28,29,30,31,32,33,35,36,37,40,42,44,46,50,52,54,57,58,59,61,62,66,67,69,70,71,74,75],"xaxis":"x","y":[16,6,48,26,19,3,10,41,37,15,17,8,9,42,22,14,31,45,63,18,8,14,31,33,4,16,2,20,14,12,5,5,48,31],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eProduct Subcategory=Meat\u003cbr\u003eCustomer Age=%{x}\u003cbr\u003eQuantity Purchased=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Meat","Meat","Meat","Meat","Meat","Meat","Meat","Meat","Meat","Meat","Meat","Meat","Meat","Meat","Meat","Meat","Meat","Meat","Meat","Meat","Meat","Meat","Meat","Meat","Meat","Meat","Meat","Meat","Meat","Meat","Meat","Meat"],"legendgroup":"Meat","marker":{"color":"#EF553B","size":[3,1,16,20,19,9,17,11,23,3,17,9,33,27,12,16,5,27,1,2,22,34,52,2,1,18,50,18,13,16,16,28],"sizemode":"area","sizeref":0.2175,"symbol":"circle"},"mode":"markers","name":"Meat","orientation":"v","showlegend":true,"x":[19,21,22,26,28,29,30,31,32,33,35,37,39,40,41,44,45,46,50,52,54,55,57,58,59,61,66,68,69,71,74,75],"xaxis":"x","y":[3,1,16,20,19,9,17,11,23,3,17,9,33,27,12,16,5,27,1,2,22,34,52,2,1,18,50,18,13,16,16,28],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eProduct Subcategory=Cleaning Supplies\u003cbr\u003eCustomer Age=%{x}\u003cbr\u003eQuantity Purchased=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Cleaning Supplies","Cleaning Supplies","Cleaning Supplies","Cleaning Supplies","Cleaning Supplies","Cleaning Supplies","Cleaning Supplies","Cleaning Supplies","Cleaning Supplies","Cleaning Supplies","Cleaning Supplies","Cleaning Supplies","Cleaning Supplies","Cleaning Supplies","Cleaning Supplies","Cleaning Supplies","Cleaning Supplies","Cleaning Supplies","Cleaning Supplies","Cleaning Supplies","Cleaning Supplies","Cleaning Supplies","Cleaning Supplies"],"legendgroup":"Cleaning Supplies","marker":{"color":"#00cc96","size":[1,3,12,9,18,46,15,27,7,18,30,9,28,5,12,29,19,16,18,35,4,87,18],"sizemode":"area","sizeref":0.2175,"symbol":"circle"},"mode":"markers","name":"Cleaning Supplies","orientation":"v","showlegend":true,"x":[20,21,24,28,29,32,39,40,42,44,46,50,52,54,55,57,59,61,62,66,69,74,75],"xaxis":"x","y":[1,3,12,9,18,46,15,27,7,18,30,9,28,5,12,29,19,16,18,35,4,87,18],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eProduct Subcategory=Seafood\u003cbr\u003eCustomer Age=%{x}\u003cbr\u003eQuantity Purchased=%{marker.size}\u003cextra\u0 ...

# %%
# Summarize data by product subcategory and gender
sunburst_data = df.groupby(['Product Subcategory', 'Customer Gender'])['Quantity Purchased'].sum().reset_index()

# Create interactive sunburst chart
fig = px.sunburst(sunburst_data, path=['Product Subcategory', 'Customer Gender'], values='Quantity Purchased',
                  title='Sunburst Chart of Quantity Purchased by Product Subcategory and Gender',
                  color='Quantity Purchased', color_continuous_scale='RdBu',
                  labels={'Quantity Purchased': 'Total Quantity Purchased', 'Product Subcategory': 'Product Subcategory', 'Customer Gender': 'Gender'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="9d684c66-489c-4fa5-a4d7-44c7c357b25d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9d684c66-489c-4fa5-a4d7-44c7c357b25d")) {                    Plotly.newPlot(                        "9d684c66-489c-4fa5-a4d7-44c7c357b25d",                        [{"branchvalues":"total","customdata":[[268.0],[201.0],[141.0],[262.0],[212.0],[265.0],[211.0],[256.0],[232.0],[254.0],[315.0],[315.0],[325.0],[421.0],[309.0],[468.0],[330.0],[254.0],[233.0],[379.0],[293.39451114922815],[270.59302325581393],[269.3261802575107],[360.0073206442167],[269.5297504798464],[394.60982264665756],[283.5878003696858],[255.00392156862745],[232.5010752688172],[328.84202211690365]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}\u003cbr\u003eQuantity Purchased_sum=%{value}\u003cbr\u003eparent=%{parent}\u003cbr\u003eid=%{id}\u003cbr\u003eTotal Quantity Purchased=%{color}\u003cextra\u003e\u003c\u002fextra\u003e","ids":["Bakery\u002fFemale","Beverages\u002fFemale","Cleaning Supplies\u002fFemale","Dairy\u002fFemale","Frozen Foods\u002fFemale","Fruits\u002fFemale","Meat\u002fFemale","Seafood\u002fFemale","Snacks\u002fFemale","Vegetables\u002fFemale","Bakery\u002fMale","Beverages\u002fMale","Cleaning Supplies\u002fMale","Dairy\u002fMale","Frozen Foods\u002fMale","Fruits\u002fMale","Meat\u002fMale","Seafood\u002fMale","Snacks\u002fMale","Vegetables\u002fMale","Bakery","Beverages","Cleaning Supplies","Dairy","Frozen Foods","Fruits","Meat","Seafood","Snacks","Vegetables"],"labels":["Female","Female","Female","Female","Female","Female","Female","Female","Female","Female","Male","Male","Male","Male","Male","Male","Male","Male","Male","Male","Bakery","Beverages","Cleaning Supplies","Dairy","Frozen Foods","Fruits","Meat","Seafood","Snacks","Vegetables"],"marker":{"coloraxis":"coloraxis","colors":[268.0,201.0,141.0,262.0,212.0,265.0,211.0,256.0,232.0,254.0,315.0,315.0,325.0,421.0,309.0,468.0,330.0,254.0,233.0,379.0,293.39451114922815,270.59302325581393,269.3261802575107,360.0073206442167,269.5297504798464,394.60982264665756,283.5878003696858,255.00392156862745,232.5010752688172,328.84202211690365]},"name":"","parents":["Bakery","Beverages","Cleaning Supplies","Dairy","Frozen Foods","Fruits","Meat","Seafood","Snacks","Vegetables","Bakery","Beverages","Cleaning Supplies","Dairy","Frozen Foods","Fruits","Meat","Seafood","Snacks","Vegetables","","","","","","","","","",""],"values":[268,201,141,262,212,265,211,256,232,254,315,315,325,421,309,468,330,254,233,379,583,516,466,683,521,733,541,510,465,633],"type":"sunburst"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.66666 ...

# %%
import plotly.express as px
import random

# Add a random US state to each customer for the purpose of this visualization
us_states = ['AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DE', 'FL', 'GA', 'HI', 'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'LA', 'ME', 'MD', 'MA', 'MI', 'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 'NM', 'NY', 'NC', 'ND', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VT', 'VA', 'WA', 'WV', 'WI', 'WY']
df['State'] = [random.choice(us_states) for _ in range(len(df))]

# Summarize data by state
state_totals = df.groupby('State')['Quantity Purchased'].sum().reset_index()

# Create interactive choropleth map
fig = px.choropleth(state_totals, locations='State', locationmode='USA-states', color='Quantity Purchased',
                    scope='usa', title='Choropleth Map of Quantity Purchased by State',
                    labels={'Quantity Purchased': 'Total Quantity Purchased'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="46bff0e9-ece0-4ff8-ad58-d8c2e39ae6e5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("46bff0e9-ece0-4ff8-ad58-d8c2e39ae6e5")) {                    Plotly.newPlot(                        "46bff0e9-ece0-4ff8-ad58-d8c2e39ae6e5",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"State=%{location}\u003cbr\u003eTotal Quantity Purchased=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","locationmode":"USA-states","locations":["AK","AL","AR","AZ","CA","CO","CT","DE","FL","GA","HI","IA","ID","IL","IN","KS","KY","LA","MA","MD","ME","MI","MN","MO","MS","MT","NC","ND","NE","NH","NJ","NM","NV","NY","OH","OK","OR","PA","RI","SC","SD","TN","TX","UT","VA","VT","WA","WI","WV","WY"],"name":"","z":[141,132,122,169,68,157,61,179,32,75,101,95,152,141,135,135,55,79,76,120,164,206,102,110,93,99,185,106,192,121,166,140,81,65,58,82,114,70,120,106,108,69,117,105,149,52,112,86,138,110],"type":"choropleth"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidt ...
